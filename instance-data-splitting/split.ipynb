# %%
print(1)
# Out:
# 1

# %%
# !python make_splits.py Instance.csv
# Out:
# Test set (n=8):
#   E-n112-k8-s11, E-n22-k4, F-n140-k5-s5, M-n212-k16-s12, X-n1006-k43-s5, X-n221-k11-s7, X-n469-k26-s10, X-n698-k75-s13
#
# 5-fold CV validation sizes:
#   fold_1: |val|=7, |train|=26
#   fold_2: |val|=7, |train|=26
#   fold_3: |val|=7, |train|=26
#   fold_4: |val|=6, |train|=27
#   fold_5: |val|=6, |train|=27
#
# Wrote splits.json
